# %%
import numpy as np
import math
from scipy.io import loadmat, savemat
import matplotlib.pyplot as plt
from scipy.spatial import distance

# %%
mask = np.load('egg_mask.npy')
well = np.load('egg_well.npy')
perm = np.load('egg_perm.npy')
print('Perm: {} | Mask: {} | Wells: {}'.format(perm.shape, mask.shape, well.shape))
# Out:
# Perm: (100, 64, 64, 8, 3) | Mask: (64, 64, 8) | Wells: (100, 64, 64)

# %%
plt.figure(figsize=(20,6))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.scatter(xe, ye, c='w', s=5)
    plt.imshow(perm[i,:,:,0,0]*mask[...,0], 'jet', alpha=0.65)
    plt.imshow(well[i], alpha=0.5)
    plt.xticks([]); plt.yticks([])
plt.show()
